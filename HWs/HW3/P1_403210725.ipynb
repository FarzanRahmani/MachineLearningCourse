# %% [markdown]
# <b><h4>HW3 - Notebook: Multi-Layer perceptron</h4></b>
#
# [CE40477: Machine Learning](https://www.sharifml.ir/)
#
# __Course Instructor__: Dr. Sharifi-Zarchi
#
# __Notebook Authors__: Amir Ezzati & Ali Bavafa
#
# Name: Farzan Rahmani
# Student-ID: 403210725

# %% [markdown]
# # Import & Helper Functions

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import gdown
from sklearn.datasets import fetch_openml
from tensorflow.keras.utils import to_categorical
from sklearn.model_selection import train_test_split
import time
import random

import torch
import torch.nn as nn
import torch.optim as optim

from torchvision import transforms
from torchvision.utils import make_grid
from torchvision.datasets import ImageFolder
from torch.utils.data import DataLoader, TensorDataset

from tqdm.auto import tqdm
from IPython.display import display

# %%
def seed_setter(seed=None, seed_torch=True):
  """
  Function that controls randomness.

  Args:
    seed : Integer
      A non-negative integer that defines the random state.
    seed_torch : Boolean
      If `True` sets the random seed for pytorch tensors.

  Returns:
    Nothing.
  """
  if seed is None:
    seed = np.random.choice(2 ** 32)
  random.seed(seed)
  np.random.seed(seed)
  if seed_torch:
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    torch.cuda.manual_seed(seed)
    torch.backends.cudnn.benchmark = False
    torch.backends.cudnn.deterministic = True

  print(f'Random seed {seed} has been set.')

# In case that `DataLoader` is used
def seed_worker(worker_id):

  worker_seed = torch.initial_seed() % 2**32
  np.random.seed(worker_seed)
  random.seed(worker_seed)

def train_test_classification(net, criterion, optimizer, train_loader,
                              test_loader, num_epochs=1, verbose=True,
                              training_plot=False):
  """
  Accumulate training loss/Evaluate performance

  Args:
    net: Instance of Net class
      Describes the model with ReLU activation, batch size 128
    criterion: torch.nn type
      Criterion combines LogSoftmax and NLLLoss in one single class.
    optimizer: torch.optim type
      Implements Adam algorithm.
    train_loader: torch.utils.data type
      Combines the train dataset and sampler, and provides an iterable over the given dataset.
    test_loader: torch.utils.data type
      Combines the test dataset and sampler, and provides an iterable over the given dataset.
    num_epochs: int
      Number of epochs [default: 1]
    verbose: boolean
      If True, print statistics
    training_plot=False
      If True, display training plot

  Returns:
    Nothing
  """
  net.train()
  train_losses = []
  for epoch in tqdm(range(num_epochs)):
    running_loss = 0.0
    for i, data in enumerate(train_loader, 0):
      # Get the inputs; data is a list of [inputs, labels]
      inputs, labels = data
      inputs = inputs.float()
      labels = labels.long()

      optimizer.zero_grad()
      outputs = net(inputs)

      loss = criterion(outputs, labels)
      loss.backward()
      optimizer.step()

      if verbose:
        train_losses += [loss.item()]

  net.eval()

  def test(data_loader):
    """
    Function to gauge network performance

    Args:
      data_loader: torch.utils.data type
        Combines the test dataset and sampler, and provides an iterable over the given dataset.

    Returns:
      acc: float
        Performance of the network
      total: int
        Number of datapoints in the dataloader
    """
    correct = 0
    total = 0
    for data in data_loader:
      inputs, labels = data
      inputs = inputs.float()
      labels = labels.long()

      outputs = net(inputs)
      _, predicted = torch.max(outputs, 1)
      total += labels.size(0)
      correct += (predicted == labels).sum().item()

    acc = 100 * correct / total
    return total, acc

  train_total, train_acc = test(train_loader)
  test_total, test_acc = test(test_loader)

  if verbose:
    print(f'\nAccuracy on the {train_total} training samples: {train_acc:0.2f}')
    print(f'Accuracy on the {test_total} testing samples: {test_acc:0.2f}\n')

  if training_plot:
    plt.plot(train_losses)
    plt.xlabel('Batch')
    plt.ylabel('Training loss')
    plt.show()

  return train_acc, test_acc

def shuffle_and_split_data(X, y, seed):
  """
  Helper function to shuffle and split data

  Args:
    X: torch.tensor
      Input data
    y: torch.tensor
      Corresponding target variables
    seed: int
      Set seed for reproducibility

  Returns:
    X_test: torch.tensor
      Test data [20% of X]
    y_test: torch.tensor
      Labels corresponding to above mentioned test data
    X_train: torch.tensor
      Train data [80% of X]
    y_train: torch.tensor
      Labels corresponding to above mentioned train data
  """
  # Set seed for reproducibility
  torch.manual_seed(seed)
  # Number of samples
  N = X.shape[0]
  # Shuffle data
  shuffled_indices = torch.randperm(N)
  X = X[shuffled_indices]
  y = y[shuffled_indices]

  test_size = int(0.2 * N)
  X_test = X[:test_size]
  y_test = y[:test_size]
  X_train = X[test_size:]
  y_train = y[test_size:]

  return X_test, y_test, X_train, y_train

def sample_grid(M=500, x_max=2.0):
  """
  Helper function to simulate sample meshgrid

  Args:
    M: int
      Size of the constructed tensor with meshgrid
    x_max: float
      Defines range for the set of points

  Returns:
    X_all: torch.tensor
      Concatenated meshgrid tensor
  """
  ii, jj = torch.meshgrid(torch.linspace(-x_max, x_max,M),
                          torch.linspace(-x_max, x_max, M),
                          indexing='ij')
  X_all = torch.cat([ii.unsqueeze(-1),
                     jj.unsqueeze(-1)],
                     dim=-1).view(-1, 2)
  return X_all

def plot_decision_map(X_all, y_pred, X_test, y_test,
                      M=500, x_max=2.0, eps=1e-3):
  """
  Helper function to plot decision map

  Args:
    X_all: torch.tensor
      Concatenated meshgrid tensor
    y_pred: torch.tensor
      Labels predicted by the network
    X_test: torch.tensor
      Test data
    y_test: torch.tensor
      Labels of the test data
    M: int
      Size of the constructed tensor with meshgrid
    x_max: float
      Defines range for the set of points
    eps: float
      Decision threshold

  Returns:
    Nothing
  """
  decision_map = torch.argmax(y_pred, dim=1)

  for i in range(len(X_test)):
    indeces = (X_all[:, 0] - X_test[i, 0])**2 + (X_all[:, 1] - X_test[i, 1])**2 < eps
    decision_map[indeces] = (K + y_test[i]).long()

  decision_map = decision_map.view(M, M).cpu()
  plt.imshow(decision_map, extent=[-x_max, x_max, -x_max, x_max], cmap='jet')
  plt.axis('off')
  plt.plot()

def plot_function_apx(x_vals, relu_activations, predicted_output):
    """
    Visualizes ReLU activations and the resulting function approximation.

    Args:
      x_vals: torch.tensor
        Input x-axis data points.
      relu_activations: torch.tensor
        Calculated ReLU activations along x-axis for each ReLU unit.
      predicted_output: torch.tensor
        Estimated output labels or function approximations (weighted sum of ReLUs).

    Returns:
      None
    """

    fig, axes = plt.subplots(2, 1, figsize=(8, 6))

    ## Plot ReLU activations
    # axes[0].plot(x_vals, relu_activations.T)
    # The problem was that relu_activations.T was a 2D tensor, and matplotlib's
    # plot function expects 1D arrays for plotting.
    # We need to iterate over the columns of relu_activations.T and plot them individually.
    for i in range(relu_activations.shape[0]):
        axes[0].plot(x_vals.detach().numpy(), relu_activations[i, :].detach().numpy())
    axes[0].set_xlabel('x-values', fontsize=12)
    axes[0].set_ylabel('Activation Levels', fontsize=12)
    axes[0].set_title('ReLU Activations (Basis Functions)', fontsize=14)
    relu_labels = [f"ReLU {i + 1}" for i in range(relu_activations.shape[0])]
    axes[0].legend(relu_labels, ncol=2)

    ## Plot the function approximation and the ground truth
    axes[1].plot(x_vals, torch.sin(x_vals), label='Ground Truth (sin(x))', color='g', linewidth=2)
    axes[1].plot(x_vals, predicted_output, label='Predicted Output', linestyle='--', color='r')
    axes[1].set_xlabel('x-values', fontsize=12)
    axes[1].set_ylabel('y(x)', fontsize=12)
    axes[1].set_title('Function Approximation vs Ground Truth', fontsize=14)
    axes[1].legend()

    plt.tight_layout(pad=2)
    plt.show()

def show_images(image, num_row=2, num_col=5):
    # plot images
    image_size = int(np.sqrt(image.shape[-1]))
    image = np.reshape(image, (image.shape[0], image_size, image_size))
    fig, axes = plt.subplots(num_row, num_col, figsize=(1.5*num_col,2*num_row))
    for i in range(num_row*num_col):
        ax = axes[i//num_col, i%num_col]
        ax.imshow(image[i], cmap='gray', vmin=0, vmax=1)
        ax.axis('off')
    plt.tight_layout()
    plt.show()

SEED = 2024
# Call `seed_setter` to ensure reproducibility.
seed_setter(seed=SEED)
# Out:
# Random seed 2024 has been set.

# %% [markdown]
# # Loading the data

# %%
# Load data
mnist_data = fetch_openml("mnist_784")
x = mnist_data["data"].astype('float').to_numpy()
y = mnist_data["target"].astype('int')

# Normalize
x /= 255.0

# One-hot encode labels
num_labels = len(np.unique(y))
y_new = to_categorical(y, num_labels)

# -------------------------------- TODO -------------------------------------
# In this section, split the data into training and test datasets, using 60,000 samples for training and the remaining samples for testing.
x_train, x_test, y_train, y_test = train_test_split(
    x, y_new, train_size=60000, test_size=10000, random_state=SEED, stratify=y
)
# -------------------------------- TODO -------------------------------------

# %%
print("Training data: {} {}".format(x_train.shape, y_train.shape))
print("Test data: {} {}".format(x_test.shape, y_test.shape))
show_images(x_train)
# Out:
# Training data: (60000, 784) (60000, 10)
# Test data: (10000, 784) (10000, 10)

# %% [markdown]
# # Activation Functions & Optimizers

# %% [markdown]
# There are many activation functions which some of them listed below. In this section you should implement them.
#
# 1. Sigmoid:
# $$
# \operatorname{sigmoid}(x) = \frac{1}{1 + \exp(-x)}
# $$
#
# 2. Softmax: $$\operatorname{softmax}(\mathbf X)_{ij} = \frac{\exp(\mathbf X_{ij})}{\sum_k \exp \mathbf X_{ik})}.$$
#
#
# 3. Tanh (Hyperbolic Tangent):
# $$
# \operatorname{tanh}(x) = \frac{\sinh(x)}{\cosh(x)} = \frac{\exp(x) - \exp(-x)}{\exp(x) + \exp(-x)}
# $$
#
# 4. ReLU: $$\operatorname{ReLU}(x) = \max(0, x)$$
#
# 5. Leaky ReLU:
# $$
# \operatorname{LeakyReLU}(x) =
# \begin{cases}
# x & \text{if } x \geq 0 \\
# \alpha x & \text{if } x < 0
# \end{cases}
# $$
# where \( $\alpha$ \) is a small constant (e.g., 0.01).
#
# 6. ELU (Exponential Linear Unit):
# $$
# \operatorname{ELU}(x) =
# \begin{cases}
# x & \text{if } x > 0 \\
# \alpha (\exp(x) - 1) & \text{if } x \leq 0
# \end{cases}
# $$
# where ($\alpha$) is a positive constant.
#
# 7. SELU (Scaled Exponential Linear Unit):
# $$
# \operatorname{SELU}(x) =
# \lambda
# \begin{cases}
# x & \text{if } x > 0 \\
# \alpha (\exp(x) - 1) & \text{if } x \leq 0
# \end{cases}
# $$
# where \( $\lambda$ \) and \( $\alpha$ \) are predefined constants, typically \( $\lambda \approx 1.0507$ \) and \( $\alpha \approx 1.67326$ \).

# %% [markdown]
# ------
# There are several optimizer algorithms for optimizing the neural network over epochs. You should implement some of those mentioned in this section:
#
# ***Stochastic Gradient Descent (SGD)***
#
# SGD is the basic form of gradient descent, where each weight (\( w \)) and bias (\( b \)) parameter is updated in the opposite direction of its gradient.
#
# **Update Rule:**
# $$
# w^{(t+1)} = w^{(t)} - \eta \cdot \nabla_w L(w^{(t)}, b^{(t)})
# $$
# $$
# b^{(t+1)} = b^{(t)} - \eta \cdot \nabla_b L(w^{(t)}, b^{(t)})
# $$
#
# - \( w \): Weight parameters
# - \( b \): Bias parameters
# - \( $\eta$ \): Learning rate
# - \( $\nabla_w L(w, b)$ \): Gradient of the loss with respect to \( w \)
# - \( $\nabla_b L(w, b)$ \): Gradient of the loss with respect to \( b \)
#
# <br><br>
#
# ***Momentum Optimizer***
#
# Momentum optimizer smooths parameter updates by adding a velocity term to accumulate past gradients.
#
# **Update Rule:**
# 1. **Velocity Update for Weights and Biases:**
#    $$
#    v_w^{(t+1)} = \beta \cdot v_w^{(t)} + (1 - \beta) \cdot \nabla_w L(w^{(t)}, b^{(t)})
#    $$
#    $$
#    v_b^{(t+1)} = \beta \cdot v_b^{(t)} + (1 - \beta) \cdot \nabla_b L(w^{(t)}, b^{(t)})
#    $$
#
# 2. **Parameter Update:**
#    $$
#    w^{(t+1)} = w^{(t)} - \eta \cdot v_w^{(t+1)}
#    $$
#    $$
#    b^{(t+1)} = b^{(t)} - \eta \cdot v_b^{(t+1)}
#    $$
#
# - \( $v_w$ \): Velocity term for weights
# - \( $v_b$ \): Velocity term for biases
# - \( $\beta$ \): Momentum term, typically set to 0.9
#
# <br><br>
#
# ***Adam Optimizer***
#
# Adam combines momentum and adaptive learning rates, using both first (momentum) and second (RMSprop) moment estimates.
#
# **Update Rule:**
# 1. **Compute biased first and second moment estimates:**
#    $$
#    m_w^{(t+1)} = \beta_1 \cdot m_w^{(t)} + (1 - \beta_1) \cdot \nabla_w L(w^{(t)}, b^{(t)})
#    $$
#    $$
#    m_b^{(t+1)} = \beta_1 \cdot m_b^{(t)} + (1 - \beta_1) \cdot \nabla_b L(w^{(t)}, b^{(t)})
#    $$
#    $$
#    v_w^{(t+1)} = \beta_2 \cdot v_w^{(t)} + (1 - \beta_2) \cdot \left( \nabla_w L(w^{(t)}, b^{(t)}) \right)^2
#    $$
#    $$
#    v_b^{(t+1)} = \beta_2 \cdot v_b^{(t)} + (1 - \beta_2) \cdot \left( \nabla_b L(w^{(t)}, b^{(t)}) \right)^2
#    $$
#
# 2. **Compute bias-corrected estimates:**
#    $$
#    \hat{m}_w^{(t+1)} = \frac{m_w^{(t+1)}}{1 - \beta_1^{t+1}}, \quad \hat{m}_b^{(t+1)} = \frac{m_b^{(t+1)}}{1 - \beta_1^{t+1}}
#    $$
#    $$
#    \hat{v}_w^{(t+1)} = \frac{v_w^{(t+1)}}{1 - \beta_2^{t+1}}, \quad \hat{v}_b^{(t+1)} = \frac{v_b^{(t+1)}}{1 - \beta_2^{t+1}}
#    $$
#
# 3. **Parameter Update:**
#    $$
#    w^{(t+1)} = w^{(t)} - \eta \cdot \frac{\hat{m}_w^{(t+1)}}{\sqrt{\hat{v}_w^{(t+1)}} + \epsilon}
#    $$
#    $$
#    b^{(t+1)} = b^{(t)} - \eta \cdot \frac{\hat{m}_b^{(t+1)}}{\sqrt{\hat{v}_b^{(t+1)}} + \epsilon}
#    $$
#
# - \( $m_w$ \), \( $m_b$ \): First moment estimates (mean of gradients) for weights and biases
# - \( $v_w$ \), \( $v_b$ \): Second moment estimates (uncentered variance of gradients) for weights and biases
# - \( $\beta_1$ \): Decay rate for first moment, typically 0.9
# - \( $\beta_2$ \): Decay rate for second moment, typically 0.999
# - \( $\epsilon$ \): Small constant for numerical stability (e.g., \(10^{-8}\))

# %% [markdown]
# # MLP from Scratch

# %%
class MLP():
    def __init__(self, sizes, activation='sigmoid'):
        self.sizes = sizes
        self.num_layers = len(sizes) - 1  # number of layers excluding input
        self.activation_name = activation

        # Choose activation function
        if activation == 'relu':
            self.activation = self.relu
        elif activation == 'sigmoid':
            self.activation = self.sigmoid
        elif activation == 'tanh':
            self.activation = self.tanh
        # -------------------------------- TODO -------------------------------------

        # Do the same for other activation functions
        elif activation == 'softmax':
            self.activation = self.softmax
        elif activation == 'leaky_relu':
            self.activation = self.leaky_relu
        elif activation == 'elu':
            self.activation = self.elu
        elif activation == 'selu':
            self.activation = self.selu

        # -------------------------------- TODO -------------------------------------
        else:
            raise ValueError("This activation function is currently not supported!")

        # Save all weights
        self.params = self.initialize()  # Initialize all weights
        # Save all intermediate values, i.e. activations
        self.cache = {}

    # Activation functions remain the same as defined in your original code
    def relu(self, x, derivative=False):
        '''
            Forward path:
            relu(x) = max(0, x)
            In other word,
            relu(x) = 0, if x < 0
                    = x, if x >= 0

            Backward path:
            ∇relu(x) = 0, if x < 0
                     = 1, if x >=0
        '''
        # -------------------------------- TODO -------------------------------------
        if derivative:
            return np.where(x > 0, 1, 0)
        else:
            return np.maximum(0, x)
        # -------------------------------- TODO -------------------------------------

    def tanh(self, x, derivative=False):
        '''
            Forward path:
            tanh(x) = (exp(x) - exp(-x)) / (exp(x) + exp(-x))

            Backward path:
            ∇tanh(x) = 1 - tanh(x)^2
        '''
        # -------------------------------- TODO -------------------------------------
        if derivative:
            return 1 - np.tanh(x)**2
        else:
            return np.tanh(x)
        # -------------------------------- TODO -------------------------------------

    def sigmoid(self, x, derivative=False):
        '''
            Forward path:
            σ(x) = 1 / 1+exp(-z)

            Backward path:
            ∇σ(x) = exp(-z) / (1+exp(-z))^2
        '''
        # -------------------------------- TODO -------------------------------------
        sig = 1 / (1 + np.exp(-x))
        if derivative:
            return sig * (1 - sig)
        else:
            return sig
        # -------------------------------- TODO -------------------------------------

    def softmax(self, x):
        '''
            softmax(x) = exp(x) / ∑exp(x)
        '''
        # Numerically stable with large exponentials
        # -------------------------------- TODO -------------------------------------
        exps = np.exp(x - np.max(x, axis=0, keepdims=True))
        return exps / np.sum(exps, axis=0, keepdims=True)
        # -------------------------------- TODO -------------------------------------

    def leaky_relu(self, x, alpha=0.01, derivative=False):
        '''
            Forward path:
            leaky_relu(x) = x if x >= 0 else αx

            Backward path:
            ∇leaky_relu(x) = 1 if x >= 0 else α
        '''
        # -------------------------------- TODO -------------------------------------
        if derivative:
            return np.where(x > 0, 1, alpha)
        else:
            return np.where(x > 0, x, alpha * x)
        # -------------------------------- TODO -------------------------------------

    def elu(self, x, alpha=1.0, derivative=False):
        '''
            Forward path:
            elu(x) = x if x > 0 else α(exp(x) - 1)

            Backward path:
            ∇elu(x) = 1 if x > 0 else α * exp(x)
        '''
        # -------------------------------- TODO -------------------------------------
        if derivative:
            return np.where(x > 0, 1, alpha * np.exp(x))
        else:
            return np.where(x > 0, x, alpha * (np.exp(x) - 1))
        # -------------------------------- TODO -------------------------------------

    def selu(self, x, lambda_=1.0507, alpha=1.67326, derivative=False):
        '''
            Forward path:
            selu(x) = λ * (x if x > 0 else α * (exp(x) - 1))

            Backward path:
            ∇selu(x) = λ * (1 if x > 0 else α * exp(x))
        '''
        # -------------------------------- TODO -------------------------------------
        if derivative:
            return lambda_ * np.where(x > 0, 1, alpha * np.exp(x))
        else:
            return lambda_ * np.where(x > 0, x, alpha * (np.exp(x) - 1))
        # -------------------------------- TODO -------------------------------------

    def initialize(self):
        params = {}
        for i in range(1, self.num_layers + 1):
            input_layer = self.sizes[i - 1]
            output_layer = self.sizes[i]
            params[f"W{i}"] = np.random.randn(output_layer, input_layer) * np.sqrt(1. / input_layer)
            params[f"b{i}"] = np.zeros((output_layer, 1))
        return params

    def feed_forward(self, x):
        self.cache["A0"] = x.T # activation 0
        # -------------------------------- TODO -------------------------------------
        # Perform feedforward pass through each hidden layer, applying weights, biases, and activation function
        for i in range(1, self.num_layers):
            Z = np.dot(self.params[f"W{i}"], self.cache[f"A{i-1}"]) + self.params[f"b{i}"]
            self.cache[f"Z{i}"] = Z
            self.cache[f"A{i}"] = self.activation(Z)

        # Output layer with softmax
        Z = np.dot(self.params[f"W{self.num_layers}"],
                self.cache[f"A{self.num_layers-1}"]) + self.params[f"b{self.num_layers}"]
        self.cache[f"Z{self.num_layers}"] = Z
        self.cache[f"A{self.num_layers}"] = self.softmax(Z)
        # -------------------------------- TODO -------------------------------------

        return self.cache[f"A{self.num_layers}"]

    def back_propagate(self, y, output):
        current_batch_size = y.shape[0]
        grads = {}

        # -------------------------------- TODO -------------------------------------
        # Backpropagate gradients through Output layer and each hidden layers
        # Output layer
        # dZ = output.T - y
        dZ = output - y.T  # Corrected line to ensure correct dimensions

        for i in range(self.num_layers, 0, -1):
            grads[f"dW{i}"] = np.dot(dZ, self.cache[f"A{i-1}"].T) / current_batch_size
            grads[f"db{i}"] = np.sum(dZ, axis=1, keepdims=True) / current_batch_size
            if i > 1:
                dA = np.dot(self.params[f"W{i}"].T, dZ)
                dZ = dA * self.activation(self.cache[f"Z{i-1}"], derivative=True)
        # -------------------------------- TODO -------------------------------------

        self.grads = grads
        return self.grads

    def cross_entropy_loss(self, y, output):
        '''
            L(y, ŷ) = −∑ylog(ŷ).
        '''
        # -------------------------------- TODO -------------------------------------
        # Compute cross-entropy loss as the negative average log-likelihood of the correct labels
        epsilon = 1e-15
        output = np.clip(output.T, epsilon, 1 - epsilon)
        l = -np.sum(y * np.log(output)) / y.shape[0]
        # -------------------------------- TODO -------------------------------------
        return l

    def initialize_momemtum_optimizer(self):
        momentum_opt = {}
        for i in range(1, self.num_layers + 1):
            # -------------------------------- TODO -------------------------------------
            # Initialize zero matrices for momentum updates of weights and biases in each layer
            for i in range(1, self.num_layers + 1):
                momentum_opt[f"VW{i}"] = np.zeros_like(self.params[f"W{i}"])
                momentum_opt[f"Vb{i}"] = np.zeros_like(self.params[f"b{i}"])
            # -------------------------------- TODO -------------------------------------
        return momentum_opt

    def initialize_adam_optimizer(self):
        adam_opt = {}
        for i in range(1, self.num_layers + 1):
            # -------------------------------- TODO -------------------------------------
            # Initialize zero matrices for first and second moment estimates of weights and biases in each layer
            adam_opt[f"mW{i}"] = np.zeros_like(self.params[f"W{i}"])
            adam_opt[f"mb{i}"] = np.zeros_like(self.params[f"b{i}"])
            adam_opt[f"vW{i}"] = np.zeros_like(self.params[f"W{i}"])
            adam_opt[f"vb{i}"] = np.zeros_like(self.params[f"b{i}"])
            # -------------------------------- TODO -------------------------------------
        return adam_opt

    def optimize(self, l_rate=0.1, beta=.9, beta1=0.9, beta2=0.999, epsilon=1e-8, t=1):

        if self.optimizer == "sgd":
            for key in self.params:
                # -------------------------------- TODO -------------------------------------
                # Update rule for SGD
                # W = W - learning_rate * dW (Standard SGD update rule)
                self.params[key] -= l_rate * self.grads["d" + key]
                # -------------------------------- TODO -------------------------------------
        elif self.optimizer == "momentum":
            for key in self.params:
                # -------------------------------- TODO -------------------------------------
                # Update rule for Momentum
                # v = beta * v + (1 - beta) * dW
                # W = W - learning_rate * v
                self.momemtum_opt["V" + key] = beta * self.momemtum_opt["V" + key] + (1 - beta) * self.grads["d" + key]
                self.params[key] -= l_rate * self.momemtum_opt["V" + key]
                # -------------------------------- TODO -------------------------------------
        elif self.optimizer == "adam":
            for key in self.params:
                # -------------------------------- TODO -------------------------------------
                # Update rule for Adam
                # First moment estimate (momentum)
                self.adam_opt["m" + key] = beta1 * self.adam_opt["m" + key] + (1 - beta1) * self.grads["d" + key]
                # Second moment estimate (velocity)
                self.adam_opt["v" + key] = beta2 * self.adam_opt["v" + key] + (1 - beta2) * (self.grads["d" + key] ** 2)

                # Bias correction
                m_hat = self.adam_opt["m" + key] / (1 - beta1 ** t)
                v_hat = self.adam_opt["v" + key] / (1 - beta2 ** t)

                # Update parameters
                self.params[key] -= l_rate * m_hat / (np.sqrt(v_hat) + epsilon)
                # -------------------------------- TODO -------------------------------------
        else:
            raise ValueError("This optimizer is currently not supported!")

    # Accuracy, loss, and training methods remain the same as defined in your original code

    def accuracy(self, y, output):
        # -------------------------------- TODO -------------------------------------
        # Calculate accuracy by comparing the pred and truth matrices
        predictions = np.argmax(output.T, axis=1)
        true_labels = np.argmax(y, axis=1)
        return np.mean(predictions == true_labels) * 100
        # -------------------------------- TODO -------------------------------------

    def train(self, x_train, y_train, x_val, y_val, epochs=10,
              batch_size=64, optimizer='momentum', l_rate=0.1, beta=.9, beta1=0.9, beta2=0.999, epsilon=1e-8, t=1):
        # Hyperparameters
        self.epochs = epochs
        self.batch_size = batch_size
        num_batches = -(-x_train.shape[0] // self.batch_size)

        # Initialize optimizer
        self.optimizer = optimizer
        if self.optimizer == 'momentum':
          self.momemtum_opt = self.initialize_momemtum_optimizer()
        elif self.optimizer == 'adam':
          self.adam_opt = self.initialize_adam_optimizer()

        start_time = time.time()

        # Train
        for i in range(self.epochs):
            # Shuffle
            permutation = np.random.permutation(x_train.shape[0])
            x_train_shuffled = x_train[permutation]
            y_train_shuffled = y_train[permutation]

            for j in range(num_batches):
                # Batch
                begin = j * self.batch_size
                end = min(begin + self.batch_size, x_train.shape[0]-1)
                x = x_train_shuffled[begin:end] # a mini batch
                y = y_train_shuffled[begin:end]

                # Forward
                output = self.feed_forward(x)
                # Backprop
                grad = self.back_propagate(y, output)
                # Optimize
                self.optimize(l_rate=l_rate, beta=beta, beta1=beta1, beta2=beta2, epsilon=epsilon, t=t)

            # Evaluate performance
            # Training data
            output = self.feed_forward(x_train)
            train_acc = self.accuracy(y_train, output)
            train_loss = self.cross_entropy_loss(y_train, output)
            # Test data
            output = self.feed_forward(x_val)
            val_acc = self.accuracy(y_val, output)
            val_loss = self.cross_entropy_loss(y_val, output)
            print(f'Epoch {i+1}: {time.time()-start_time:.2f}s, train acc={train_acc:.2f}, train loss={train_loss:.2f}, '
                      f'validation acc={val_acc:.2f}, validation loss={val_loss:.2f}')

    def evaluate(self, x_test, y_test):
        # Test data
        output = self.feed_forward(x_test)
        test_acc = self.accuracy(y_test, output)
        test_loss = self.cross_entropy_loss(y_test, output)
        print(f'\nTest acc={test_acc:.2f}, Test loss={test_loss:.2f}')

# %% [markdown]
# Please run experiments with different combinations of optimizers (SGD, Momentum, and Adam) and activation functions (ReLU, Sigmoid, Tanh, Leaky ReLU, SELU, and ELU) over 20 epochs each. Consider networks with three layers (without input layer) whose number of neurons is 128, 64 and 10 respectively. Also consider two learning rates 0.01 and 0.001.
#
#
# After testing all combinations, report which combination of optimizer, activation function, and learning rate performs best.

# %%
# Run your experiments here ...

def run_experiments():
    # Network architecture
    architecture = [784, 128, 64, 10]

    # Configurations
    optimizers = ['sgd', 'momentum', 'adam']
    activations = ['relu', 'sigmoid', 'tanh', 'leaky_relu', 'elu', 'selu']
    learning_rates = [0.01, 0.001]

    best_val_acc = 0
    best_config = None

    results = []

    for opt in optimizers:
        for act in activations:
            for lr in learning_rates:
                print(f"\nTesting: {opt} optimizer, {act} activation, lr={lr}")

                # Initialize model
                model = MLP(architecture, activation=act)

                # Train model
                model.train(x_train, y_train, x_test, y_test,
                          epochs=20, batch_size=64,
                          optimizer=opt, l_rate=lr)

                # Get final validation accuracy
                output = model.feed_forward(x_test)
                val_acc = model.accuracy(y_test, output)

                results.append({
                    'optimizer': opt,
                    'activation': act,
                    'learning_rate': lr,
                    'val_accuracy': val_acc
                })

                if val_acc > best_val_acc:
                    best_val_acc = val_acc
                    best_config = (opt, act, lr)

    return results, best_config, best_val_acc

# Run experiments
results, best_config, best_val_acc = run_experiments()

# Print best configuration
print("\nBest configuration:")
print(f"Optimizer: {best_config[0]}")
print(f"Activation: {best_config[1]}")
print(f"Learning rate: {best_config[2]}")
print(f"Validation accuracy: {best_val_acc:.2f}%")
# Out:
# Testing: sgd optimizer, relu activation, lr=0.01
# Epoch 1: 3.28s, train acc=87.56, train loss=0.47, validation acc=87.62, validation loss=0.46
# Epoch 2: 6.13s, train acc=90.25, train loss=0.35, validation acc=90.67, validation loss=0.34
# Epoch 3: 8.97s, train acc=91.39, train loss=0.30, validation acc=91.73, validation loss=0.30
# Epoch 4: 14.23s, train acc=92.03, train loss=0.28, validation acc=92.31, validation loss=0.28
# Epoch 5: 17.11s, train acc=92.71, train loss=0.26, validation acc=92.69, validation loss=0.26
# Epoch 6: 19.96s, train acc=93.26, train loss=0.23, validation acc=93.25, validation loss=0.24
# Epoch 7: 22.74s, train acc=93.56, train loss=0.22, validation acc=93.45, validation loss=0.23
# Epoch 8: 26.60s, train acc=93.94, train loss=0.21, validation acc=93.75, validation loss=0.22
# Epoch 9: 30.86s, train acc=94.49, train loss=0.19, validation acc=94.12, validation loss=0.20
# Epoch 10: 33.93s, train acc=94.80, train loss=0.18, validation acc=94.47, validation loss=0.19
# Epoch 11: 36.80s, train acc=95.09, train loss=0.17, validation acc=94.71, validation loss=0.18
# Epoch 12: 39.90s, train acc=95.35, train loss=0.16, validation acc=94.81, validation loss=0.18
# Epoch 13: 44.91s, train acc=95.59, train loss=0.16, validation acc=94.94, validation loss=0.17
# Epoch 14: 47.89s, train acc=95.79, train loss=0.15, validation acc=95.22, validation loss=0.16
# Epoch 15: 51.76s, train acc=95.97, train loss=0.14, validation acc=95.34, validation loss=0.16
# Epoch 16: 54.83s, train acc=96.14, train loss=0.14, validation acc=95.41, validation loss=0.15
# Epoch 17: 60.68s, train acc=96.40, train loss=0.13, validation acc=95.70, validation loss=0.15
# Epoch 18: 64.53s, train acc=96.55, train loss=0.12, validation acc=95.81, validation loss=0.14
# Epoch 19: 67.49s, train acc=96.63, train loss=0.12, validation acc=96.00, validation loss=0.14
# Epoch 20: 74.54s, train acc=96.70, train loss=0.11, validation acc=95.87, validation loss=0.14
#
# Testing: sgd optimizer, relu activation, lr=0.001
# Epoch 1: 3.64s, train acc=43.29, train loss=2.07, validation acc=43.98, validation loss=2.07
# Epoch 2: 6.43s, train acc=64.42, train loss=1.74, validation acc=64.80, validation loss=1.73
# Epoch 3: 11.58s, train acc=76.28, train loss=1.32, validation acc=76.70, validation loss=1.32
# Epoch 4: 17.16s, train acc=80.79, train loss=0.99, validation acc=81.37, validation loss=0.99
# Epoch 5: 20.54s, train acc=82.82, train loss=0.79, validation acc=83.15, validation loss=0.78
# Epoch 6: 24.03s, train acc=84.31, train loss=0.67, validation acc=84.50, validation loss=0.66
# Epoch 7: 30.10s, train acc=85.51, train loss=0.60, validation acc=85.74, validation loss=0.59
# Epoch 8: 34.22s, train acc=86.27, train loss=0.54, validation acc=86.48, validation loss=0.54
# Epoch 9: 37.02s, train acc=86.97, train loss=0.50, validation acc=87.34, validation loss=0.50
# Epoch 10: 42.98s, train acc=87.46, train loss=0.47, validation acc=87.86, validation loss=0.47
# Epoch 11: 46.65s, train acc=87.97, train loss=0.45, validation acc=88.30, validation loss=0.44
# Epoch 12: 49.50s, train acc=88.31, train loss=0.43, validation acc=88.69, validation loss=0.43
# Epoch 13: 53.26s, train acc=88.63, train loss=0.42, validation acc=89.01, validation loss=0.41
# Epoch 14: 59.25s, train acc=88.88, train loss=0.40, validation acc=89.27, validation loss=0.40
# Epoch 15: 63.39s, train acc=89.06, train loss=0.39, validation acc=89.60, validation loss=0.39
# Epoch 16: 66.18s, train acc=89.30, train loss=0.38, validation acc=89.79, validation loss=0.38
# Epoch 17: 72.31s, train acc=89.48, train loss=0.37, validation acc=90.03, validation loss=0.37
# Epoch 18: 76.24s, train acc=89.66, train loss=0.37, validation acc=90.13, validation loss=0.36
# Epoch 19: 80.11s, train acc=89.86, train loss=0.36, validation acc=90.33, validation loss=0.36
# Epoch 20: 83.14s, train acc=90.00, train loss=0.35, validation acc=90.49, validation loss=0.35
#
# Testing: sgd optimizer, sigmoid activation, lr=0.01
# Epoch 1: 5.82s, train acc=14.48, train loss=2.27, validation acc=14.39, validation loss=2.27
# Epoch 2: 9.28s, train acc=26.84, train loss=2.21, validation acc=26.86, validation loss=2.21
# Epoch 3: 12.64s, train acc=51.69, train loss=2.08, validation acc=51.94, validation loss=2.08
# Epoch 4: 18.20s, train acc=58.06, train loss=1.82, validation acc=58.03, validation loss=1.82
# Epoch 5: 22.26s, train acc=61.94, train loss=1.48, validation acc=62.06, validation loss=1.48
# Epoch 17: 72.33s, train acc=41.81, train loss=2.21, validation acc=41.92, validation loss=2.21
# Epoch 18: 75.70s, train acc=44.63, train loss=2.20, validation acc=44.95, validation loss=2.20
# Epoch 19: 79.23s, train acc=44.80, train loss=2.19, validation acc=44.87, validation loss=2.19
# Epoch 20: 84.86s, train acc=47.46, train loss=2.18, validation acc=47.70, validation loss=2.18
#
# Testing: sgd optimizer, tanh activation, lr=0.01
# Epoch 1: 5.16s, train acc=87.28, train loss=0.50, validation acc=87.50, validation loss=0.50
# Epoch 2: 11.94s, train acc=89.79, train loss=0.38, validation acc=89.86, validation loss=0.37
# Epoch 3: 19.99s, train acc=90.77, train loss=0.33, validation acc=91.07, validation loss=0.33
# Epoch 4: 26.41s, train acc=91.43, train loss=0.30, validation acc=91.83, validation loss=0.30
# Epoch 5: 32.16s, train acc=91.92, train loss=0.28, validation acc=92.07, validation loss=0.28
# Epoch 6: 37.26s, train acc=92.48, train loss=0.26, validation acc=92.51, validation loss=0.26
# Epoch 7: 44.82s, train acc=92.86, train loss=0.25, validation acc=92.86, validation loss=0.25
# Epoch 8: 49.98s, train acc=93.20, train loss=0.24, validation acc=92.98, validation loss=0.24
# Epoch 9: 57.00s, train acc=93.50, train loss=0.23, validation acc=93.39, validation loss=0.23
# Epoch 10: 62.34s, train acc=93.79, train loss=0.22, validation acc=93.60, validation loss=0.22
# Epoch 11: 67.78s, train acc=94.02, train loss=0.21, validation acc=93.79, validation loss=0.21
# Epoch 12: 77.07s, train acc=94.28, train loss=0.20, validation acc=94.00, validation loss=0.21
# Epoch 13: 82.91s, train acc=94.55, train loss=0.19, validation acc=94.29, validation loss=0.20
# Epoch 14: 90.69s, train acc=94.73, train loss=0.18, validation acc=94.44, validation loss=0.19
# Epoch 15: 96.97s, train acc=94.95, train loss=0.17, validation acc=94.69, validation loss=0.19
# Epoch 16: 104.66s, train acc=95.14, train loss=0.17, validation acc=94.77, validation loss=0.18
# Epoch 17: 109.78s, train acc=95.36, train loss=0.16, validation acc=94.96, validation loss=0.17
# Epoch 18: 116.84s, train acc=95.48, train loss=0.16, validation acc=95.03, validation loss=0.17
# Epoch 19: 121.95s, train acc=95.67, train loss=0.15, validation acc=95.13, validation loss=0.17
# Epoch 20: 127.45s, train acc=95.85, train loss=0.15, validation acc=95.23, validation loss=0.16
#
# Testing: sgd optimizer, tanh activation, lr=0.001
# Epoch 1: 6.84s, train acc=69.64, train loss=1.63, validation acc=69.59, validation loss=1.63
# Epoch 2: 11.90s, train acc=77.40, train loss=1.23, validation acc=76.93, validation loss=1.23
# Epoch 3: 19.59s, train acc=80.73, train loss=0.99, validation acc=80.43, validation loss=0.99
# Epoch 4: 24.63s, train acc=83.01, train loss=0.84, validation acc=82.93, validation loss=0.84
# Epoch 5: 30.49s, train acc=84.40, train loss=0.74, validation acc=84.53, validation loss=0.73
# Epoch 6: 36.45s, train acc=85.31, train loss=0.66, validation acc=85.51, validation loss=0.66
# Epoch 7: 41.47s, train acc=86.11, train loss=0.61, validation acc=86.26, validation loss=0.61
# Epoch 8: 48.97s, train acc=86.78, train loss=0.57, validation acc=86.83, validation loss=0.57
# Epoch 20: 71.96s, train acc=96.82, train loss=0.12, validation acc=96.01, validation loss=0.14
#
# Testing: sgd optimizer, leaky_relu activation, lr=0.001
# Epoch 1: 2.93s, train acc=36.04, train loss=2.11, validation acc=35.64, validation loss=2.11
# Epoch 2: 5.89s, train acc=65.43, train loss=1.75, validation acc=65.58, validation loss=1.75
# Epoch 3: 8.89s, train acc=76.21, train loss=1.31, validation acc=76.10, validation loss=1.31
# Epoch 4: 14.03s, train acc=80.76, train loss=0.98, validation acc=80.78, validation loss=0.97
# Epoch 5: 17.13s, train acc=83.39, train loss=0.78, validation acc=83.74, validation loss=0.77
# Epoch 6: 20.03s, train acc=84.86, train loss=0.66, validation acc=85.12, validation loss=0.66
# Epoch 7: 22.92s, train acc=86.07, train loss=0.59, validation acc=86.26, validation loss=0.58
# Epoch 8: 27.10s, train acc=86.85, train loss=0.54, validation acc=86.86, validation loss=0.53
# Epoch 9: 31.13s, train acc=87.60, train loss=0.50, validation acc=87.57, validation loss=0.49
# Epoch 10: 34.04s, train acc=87.99, train loss=0.47, validation acc=88.06, validation loss=0.46
# Epoch 11: 37.03s, train acc=88.40, train loss=0.44, validation acc=88.45, validation loss=0.44
# Epoch 12: 40.24s, train acc=88.72, train loss=0.43, validation acc=88.91, validation loss=0.42
# Epoch 13: 45.27s, train acc=89.03, train loss=0.41, validation acc=89.12, validation loss=0.41
# Epoch 14: 48.16s, train acc=89.23, train loss=0.40, validation acc=89.38, validation loss=0.40
# Epoch 15: 51.09s, train acc=89.43, train loss=0.39, validation acc=89.73, validation loss=0.38
# Epoch 16: 53.95s, train acc=89.60, train loss=0.38, validation acc=89.81, validation loss=0.38
# Epoch 17: 59.67s, train acc=89.80, train loss=0.37, validation acc=90.23, validation loss=0.37
# Epoch 18: 62.57s, train acc=89.95, train loss=0.36, validation acc=90.40, validation loss=0.36
# Epoch 19: 69.13s, train acc=90.10, train loss=0.35, validation acc=90.37, validation loss=0.35
# Epoch 20: 76.78s, train acc=90.27, train loss=0.35, validation acc=90.66, validation loss=0.35
#
# Testing: sgd optimizer, elu activation, lr=0.01
# Epoch 1: 3.64s, train acc=88.01, train loss=0.44, validation acc=88.29, validation loss=0.43
# Epoch 2: 7.23s, train acc=90.16, train loss=0.35, validation acc=90.52, validation loss=0.34
# Epoch 3: 13.68s, train acc=91.02, train loss=0.31, validation acc=91.53, validation loss=0.31
# Epoch 4: 17.31s, train acc=91.57, train loss=0.29, validation acc=91.97, validation loss=0.29
# Epoch 5: 20.88s, train acc=92.07, train loss=0.28, validation acc=92.48, validation loss=0.28
# Epoch 6: 26.33s, train acc=92.53, train loss=0.26, validation acc=92.63, validation loss=0.26
# Epoch 7: 30.30s, train acc=92.75, train loss=0.25, validation acc=92.74, validation loss=0.26
# Epoch 8: 34.01s, train acc=93.08, train loss=0.24, validation acc=93.27, validation loss=0.24
# Epoch 9: 38.08s, train acc=93.52, train loss=0.23, validation acc=93.50, validation loss=0.23
# Epoch 10: 44.95s, train acc=93.81, train loss=0.22, validation acc=93.66, validation loss=0.23
# Epoch 11: 48.51s, train acc=94.08, train loss=0.21, validation acc=93.89, validation loss=0.22
# Epoch 12: 52.28s, train acc=94.27, train loss=0.20, validation acc=94.03, validation loss=0.21
# Epoch 13: 58.12s, train acc=94.56, train loss=0.19, validation acc=94.22, validation loss=0.20
# Epoch 14: 61.64s, train acc=94.72, train loss=0.18, validation acc=94.32, validation loss=0.19
# Epoch 15: 65.26s, train acc=94.89, train loss=0.18, validation acc=94.39, validation loss=0.19
# Epoch 16: 71.43s, train acc=95.09, train loss=0.17, validation acc=94.63, validation loss=0.18
# Epoch 17: 75.02s, train acc=95.26, train loss=0.17, validation acc=94.78, validation loss=0.18
# Epoch 18: 78.64s, train acc=95.49, train loss=0.16, validation acc=94.97, validation loss=0.17
# Epoch 19: 82.95s, train acc=95.55, train loss=0.15, validation acc=95.15, validation loss=0.17
# Epoch 20: 88.27s, train acc=95.70, train loss=0.15, validation acc=95.28, validation loss=0.16
#
# Testing: sgd optimizer, elu activation, lr=0.001
# Epoch 1: 3.68s, train acc=65.10, train loss=1.71, validation acc=65.68, validation loss=1.70
# Epoch 2: 7.33s, train acc=74.41, train loss=1.25, validation acc=74.98, validation loss=1.24
# Epoch 3: 13.72s, train acc=79.90, train loss=0.95, validation acc=80.84, validation loss=0.94
# Epoch 4: 17.24s, train acc=82.95, train loss=0.77, validation acc=83.42, validation loss=0.76
# Epoch 5: 20.86s, train acc=84.60, train loss=0.66, validation acc=84.89, validation loss=0.65
# Epoch 6: 25.89s, train acc=85.65, train loss=0.58, validation acc=86.00, validation loss=0.57
# Epoch 7: 30.39s, train acc=86.66, train loss=0.53, validation acc=86.80, validation loss=0.52
# Epoch 8: 33.96s, train acc=87.21, train loss=0.50, validation acc=87.28, validation loss=0.49
# Epoch 9: 37.60s, train acc=87.74, train loss=0.47, validation acc=87.84, validation loss=0.46
# Epoch 10: 43.55s, train acc=88.17, train loss=0.45, validation acc=88.33, validation loss=0.44
# Epoch 11: 47.11s, train acc=88.46, train loss=0.43, validation acc=88.74, validation loss=0.42
# Epoch 12: 50.70s, train acc=88.68, train loss=0.41, validation acc=88.97, validation loss=0.41
# Epoch 13: 56.25s, train acc=89.00, train loss=0.40, validation acc=89.29, validation loss=0.40
# Epoch 14: 60.17s, train acc=89.14, train loss=0.39, validation acc=89.46, validation loss=0.39
# Epoch 15: 63.81s, train acc=89.29, train loss=0.38, validation acc=89.66, validation loss=0.38
# Epoch 16: 67.68s, train acc=89.51, train loss=0.38, validation acc=89.90, validation loss=0.37
# Epoch 17: 73.38s, train acc=89.62, train loss=0.37, validation acc=90.04, validation loss=0.36
# Epoch 18: 76.95s, train acc=89.81, train loss=0.36, validation acc=90.20, validation loss=0.36
# Epoch 19: 80.58s, train acc=89.94, train loss=0.36, validation acc=90.30, validation loss=0.35
# Epoch 20: 86.37s, train acc=90.05, train loss=0.35, validation acc=90.45, validation loss=0.35
#
# Testing: sgd optimizer, selu activation, lr=0.01
# Epoch 1: 3.65s, train acc=89.48, train loss=0.38, validation acc=89.70, validation loss=0.38
# Epoch 2: 7.30s, train acc=90.99, train loss=0.32, validation acc=91.33, validation loss=0.31
# Epoch 17: 77.32s, train acc=88.02, train loss=0.44, validation acc=88.34, validation loss=0.44
# Epoch 18: 83.51s, train acc=88.38, train loss=0.43, validation acc=88.71, validation loss=0.42
# Epoch 19: 87.30s, train acc=88.73, train loss=0.41, validation acc=89.06, validation loss=0.41
# Epoch 20: 91.09s, train acc=89.00, train loss=0.40, validation acc=89.19, validation loss=0.40
#
# Testing: momentum optimizer, sigmoid activation, lr=0.001
# Epoch 1: 5.91s, train acc=16.05, train loss=2.31, validation acc=16.53, validation loss=2.31
# Epoch 2: 10.19s, train acc=11.29, train loss=2.29, validation acc=11.31, validation loss=2.29
# Epoch 3: 14.02s, train acc=11.26, train loss=2.29, validation acc=11.27, validation loss=2.29
# Epoch 4: 18.46s, train acc=11.25, train loss=2.28, validation acc=11.25, validation loss=2.28
# Epoch 5: 23.96s, train acc=11.25, train loss=2.28, validation acc=11.26, validation loss=2.28
# Epoch 6: 27.82s, train acc=11.39, train loss=2.27, validation acc=11.40, validation loss=2.27
# Epoch 7: 31.65s, train acc=11.71, train loss=2.27, validation acc=11.76, validation loss=2.27
# Epoch 8: 38.30s, train acc=12.07, train loss=2.26, validation acc=12.17, validation loss=2.26
# Epoch 9: 42.16s, train acc=15.50, train loss=2.26, validation acc=15.46, validation loss=2.26
# Epoch 10: 46.02s, train acc=18.19, train loss=2.25, validation acc=18.14, validation loss=2.25
# Epoch 11: 52.50s, train acc=22.09, train loss=2.25, validation acc=22.10, validation loss=2.25
# Epoch 12: 56.35s, train acc=25.13, train loss=2.24, validation acc=25.27, validation loss=2.24
# Epoch 13: 60.19s, train acc=27.85, train loss=2.23, validation acc=27.79, validation loss=2.23
# Epoch 14: 66.36s, train acc=33.02, train loss=2.23, validation acc=33.11, validation loss=2.23
# Epoch 15: 70.16s, train acc=34.13, train loss=2.22, validation acc=34.49, validation loss=2.22
# Epoch 16: 73.97s, train acc=39.71, train loss=2.21, validation acc=40.07, validation loss=2.21
# Epoch 17: 78.69s, train acc=39.33, train loss=2.20, validation acc=39.65, validation loss=2.20
# Epoch 18: 83.62s, train acc=42.00, train loss=2.19, validation acc=42.11, validation loss=2.19
# Epoch 19: 87.45s, train acc=45.48, train loss=2.18, validation acc=45.52, validation loss=2.18
# Epoch 20: 91.61s, train acc=49.80, train loss=2.17, validation acc=50.13, validation loss=2.17
#
# Testing: momentum optimizer, tanh activation, lr=0.01
# Epoch 1: 7.55s, train acc=87.67, train loss=0.51, validation acc=87.51, validation loss=0.50
# Epoch 2: 13.13s, train acc=89.85, train loss=0.38, validation acc=89.94, validation loss=0.37
# Epoch 3: 21.26s, train acc=90.79, train loss=0.33, validation acc=90.83, validation loss=0.33
# Epoch 4: 26.75s, train acc=91.44, train loss=0.30, validation acc=91.69, validation loss=0.30
# Epoch 5: 35.04s, train acc=91.94, train loss=0.28, validation acc=92.23, validation loss=0.28
# Epoch 6: 40.61s, train acc=92.34, train loss=0.27, validation acc=92.46, validation loss=0.27
# Epoch 7: 48.27s, train acc=92.72, train loss=0.25, validation acc=92.82, validation loss=0.26
# Epoch 20: 132.78s, train acc=89.95, train loss=0.38, validation acc=90.53, validation loss=0.37
#
# Testing: momentum optimizer, leaky_relu activation, lr=0.01
# Epoch 1: 3.97s, train acc=87.79, train loss=0.47, validation acc=87.83, validation loss=0.46
# Epoch 2: 7.36s, train acc=90.24, train loss=0.35, validation acc=90.52, validation loss=0.34
# Epoch 3: 10.73s, train acc=91.35, train loss=0.30, validation acc=91.85, validation loss=0.30
# Epoch 4: 16.69s, train acc=92.24, train loss=0.27, validation acc=92.40, validation loss=0.27
# Epoch 5: 19.99s, train acc=92.88, train loss=0.25, validation acc=92.92, validation loss=0.25
# Epoch 6: 23.36s, train acc=93.39, train loss=0.23, validation acc=93.40, validation loss=0.24
# Epoch 7: 26.82s, train acc=93.86, train loss=0.22, validation acc=93.80, validation loss=0.22
# Epoch 8: 32.41s, train acc=94.25, train loss=0.20, validation acc=94.13, validation loss=0.21
# Epoch 9: 35.90s, train acc=94.50, train loss=0.19, validation acc=94.43, validation loss=0.20
# Epoch 10: 39.25s, train acc=94.78, train loss=0.18, validation acc=94.42, validation loss=0.19
# Epoch 11: 44.10s, train acc=95.10, train loss=0.17, validation acc=94.82, validation loss=0.18
# Epoch 12: 48.29s, train acc=95.44, train loss=0.16, validation acc=94.97, validation loss=0.18
# Epoch 13: 51.71s, train acc=95.70, train loss=0.15, validation acc=95.16, validation loss=0.17
# Epoch 14: 55.09s, train acc=95.85, train loss=0.15, validation acc=95.30, validation loss=0.16
# Epoch 15: 60.88s, train acc=96.10, train loss=0.14, validation acc=95.41, validation loss=0.16
# Epoch 16: 64.19s, train acc=96.25, train loss=0.13, validation acc=95.68, validation loss=0.15
# Epoch 17: 67.54s, train acc=96.37, train loss=0.13, validation acc=95.75, validation loss=0.15
# Epoch 18: 71.43s, train acc=96.48, train loss=0.13, validation acc=95.79, validation loss=0.14
# Epoch 19: 76.71s, train acc=96.60, train loss=0.12, validation acc=96.02, validation loss=0.14
# Epoch 20: 80.06s, train acc=96.86, train loss=0.11, validation acc=96.07, validation loss=0.13
#
# Testing: momentum optimizer, leaky_relu activation, lr=0.001
# Epoch 1: 3.50s, train acc=36.51, train loss=2.11, validation acc=36.71, validation loss=2.11
# Epoch 2: 9.27s, train acc=60.28, train loss=1.79, validation acc=60.65, validation loss=1.79
# Epoch 3: 13.03s, train acc=73.59, train loss=1.39, validation acc=73.98, validation loss=1.38
# Epoch 4: 16.57s, train acc=78.97, train loss=1.05, validation acc=79.47, validation loss=1.04
# Epoch 5: 20.01s, train acc=82.34, train loss=0.83, validation acc=82.40, validation loss=0.82
# Epoch 6: 25.95s, train acc=84.34, train loss=0.69, validation acc=84.31, validation loss=0.68
# Epoch 7: 29.30s, train acc=85.63, train loss=0.60, validation acc=85.73, validation loss=0.60
# Epoch 8: 32.82s, train acc=86.65, train loss=0.54, validation acc=86.87, validation loss=0.54
# Epoch 9: 37.69s, train acc=87.40, train loss=0.50, validation acc=87.58, validation loss=0.49
# Epoch 10: 42.09s, train acc=87.92, train loss=0.47, validation acc=88.24, validation loss=0.46
# Epoch 11: 45.59s, train acc=88.29, train loss=0.44, validation acc=88.80, validation loss=0.44
# Epoch 12: 48.98s, train acc=88.58, train loss=0.42, validation acc=89.08, validation loss=0.42
# Epoch 13: 54.80s, train acc=88.92, train loss=0.41, validation acc=89.39, validation loss=0.40
# Epoch 14: 58.24s, train acc=89.20, train loss=0.39, validation acc=89.72, validation loss=0.39
# Epoch 15: 61.67s, train acc=89.42, train loss=0.38, validation acc=89.90, validation loss=0.38
# Epoch 16: 66.12s, train acc=89.64, train loss=0.37, validation acc=90.06, validation loss=0.37
# Epoch 17: 70.91s, train acc=89.83, train loss=0.36, validation acc=90.31, validation loss=0.36
# Epoch 18: 74.29s, train acc=89.96, train loss=0.36, validation acc=90.48, validation loss=0.35
# Epoch 19: 77.77s, train acc=90.15, train loss=0.35, validation acc=90.49, validation loss=0.34
# Epoch 20: 83.79s, train acc=90.33, train loss=0.34, validation acc=90.79, validation loss=0.34
#
# Testing: momentum optimizer, elu activation, lr=0.01
# Epoch 1: 4.08s, train acc=88.03, train loss=0.44, validation acc=88.18, validation loss=0.43
# Epoch 2: 8.14s, train acc=90.00, train loss=0.35, validation acc=90.25, validation loss=0.35
# Epoch 3: 14.61s, train acc=90.83, train loss=0.32, validation acc=90.97, validation loss=0.32
# Epoch 4: 18.64s, train acc=91.33, train loss=0.30, validation acc=91.52, validation loss=0.30
# Epoch 5: 22.71s, train acc=91.78, train loss=0.29, validation acc=91.88, validation loss=0.29
# Epoch 6: 28.97s, train acc=92.17, train loss=0.28, validation acc=92.19, validation loss=0.28
# Epoch 7: 32.97s, train acc=92.38, train loss=0.27, validation acc=92.22, validation loss=0.27
# Epoch 8: 37.03s, train acc=92.74, train loss=0.25, validation acc=92.51, validation loss=0.26
# Epoch 9: 42.64s, train acc=92.97, train loss=0.24, validation acc=92.90, validation loss=0.25
# Epoch 10: 47.40s, train acc=93.28, train loss=0.24, validation acc=93.09, validation loss=0.24
# Epoch 11: 51.40s, train acc=93.62, train loss=0.22, validation acc=93.28, validation loss=0.23
# Epoch 12: 56.70s, train acc=93.90, train loss=0.22, validation acc=93.54, validation loss=0.22
# Epoch 13: 61.85s, train acc=94.16, train loss=0.21, validation acc=93.81, validation loss=0.22
# Epoch 14: 65.89s, train acc=94.25, train loss=0.20, validation acc=93.90, validation loss=0.21
# Epoch 15: 70.45s, train acc=94.64, train loss=0.19, validation acc=94.12, validation loss=0.20
# Epoch 16: 76.14s, train acc=94.75, train loss=0.18, validation acc=94.15, validation loss=0.20
# Epoch 17: 80.16s, train acc=94.97, train loss=0.18, validation acc=94.32, validation loss=0.19
# Epoch 18: 84.78s, train acc=95.16, train loss=0.17, validation acc=94.61, validation loss=0.18
# Epoch 19: 90.72s, train acc=95.30, train loss=0.17, validation acc=94.54, validation loss=0.18
# Epoch 20: 94.75s, train acc=95.41, train loss=0.16, validation acc=94.75, validation loss=0.17
#
# Testing: momentum optimizer, elu activation, lr=0.001
# Epoch 1: 4.28s, train acc=65.41, train loss=1.67, validation acc=65.66, validation loss=1.66
# Epoch 14: 66.98s, train acc=95.11, train loss=0.17, validation acc=94.56, validation loss=0.19
# Epoch 15: 72.90s, train acc=95.36, train loss=0.16, validation acc=94.81, validation loss=0.18
# Epoch 16: 77.31s, train acc=95.56, train loss=0.16, validation acc=94.90, validation loss=0.18
# Epoch 17: 81.36s, train acc=95.76, train loss=0.15, validation acc=94.95, validation loss=0.17
# Epoch 18: 86.72s, train acc=95.84, train loss=0.14, validation acc=95.14, validation loss=0.17
# Epoch 19: 91.74s, train acc=96.11, train loss=0.14, validation acc=95.38, validation loss=0.16
# Epoch 20: 95.77s, train acc=96.20, train loss=0.13, validation acc=95.48, validation loss=0.16
#
# Testing: momentum optimizer, selu activation, lr=0.001
# Epoch 1: 5.29s, train acc=76.78, train loss=1.12, validation acc=77.82, validation loss=1.11
# Epoch 2: 10.59s, train acc=82.35, train loss=0.77, validation acc=82.90, validation loss=0.76
# Epoch 3: 14.62s, train acc=84.77, train loss=0.62, validation acc=85.24, validation loss=0.61
# Epoch 4: 19.29s, train acc=86.30, train loss=0.54, validation acc=86.54, validation loss=0.53
# Epoch 5: 24.91s, train acc=87.23, train loss=0.49, validation acc=87.53, validation loss=0.48
# Epoch 6: 28.93s, train acc=87.92, train loss=0.46, validation acc=88.25, validation loss=0.45
# Epoch 7: 33.24s, train acc=88.47, train loss=0.43, validation acc=88.85, validation loss=0.42
# Epoch 8: 39.37s, train acc=88.86, train loss=0.41, validation acc=89.25, validation loss=0.40
# Epoch 9: 43.39s, train acc=89.22, train loss=0.39, validation acc=89.62, validation loss=0.39
# Epoch 10: 47.51s, train acc=89.42, train loss=0.38, validation acc=89.80, validation loss=0.38
# Epoch 11: 54.01s, train acc=89.67, train loss=0.37, validation acc=90.09, validation loss=0.36
# Epoch 12: 58.07s, train acc=89.90, train loss=0.36, validation acc=90.33, validation loss=0.36
# Epoch 13: 62.16s, train acc=90.06, train loss=0.35, validation acc=90.57, validation loss=0.35
# Epoch 14: 68.70s, train acc=90.26, train loss=0.35, validation acc=90.72, validation loss=0.34
# Epoch 15: 72.70s, train acc=90.44, train loss=0.34, validation acc=90.85, validation loss=0.34
# Epoch 16: 76.69s, train acc=90.55, train loss=0.33, validation acc=91.03, validation loss=0.33
# Epoch 17: 83.29s, train acc=90.70, train loss=0.33, validation acc=91.11, validation loss=0.33
# Epoch 18: 87.34s, train acc=90.80, train loss=0.32, validation acc=91.22, validation loss=0.32
# Epoch 19: 91.36s, train acc=90.92, train loss=0.32, validation acc=91.24, validation loss=0.32
# Epoch 20: 97.94s, train acc=91.00, train loss=0.32, validation acc=91.29, validation loss=0.31
#
# Testing: adam optimizer, relu activation, lr=0.01
# Epoch 1: 4.18s, train acc=97.27, train loss=0.09, validation acc=96.71, validation loss=0.11
# Epoch 2: 8.33s, train acc=97.80, train loss=0.07, validation acc=96.71, validation loss=0.12
# Epoch 3: 15.04s, train acc=98.70, train loss=0.04, validation acc=97.23, validation loss=0.10
# Epoch 4: 19.19s, train acc=98.77, train loss=0.04, validation acc=97.10, validation loss=0.10
# Epoch 5: 23.54s, train acc=98.74, train loss=0.04, validation acc=97.16, validation loss=0.11
# Epoch 6: 30.28s, train acc=99.03, train loss=0.03, validation acc=97.54, validation loss=0.11
# Epoch 7: 34.40s, train acc=99.10, train loss=0.03, validation acc=97.26, validation loss=0.11
# Epoch 8: 41.47s, train acc=99.06, train loss=0.03, validation acc=97.30, validation loss=0.12
# Epoch 9: 47.93s, train acc=99.09, train loss=0.03, validation acc=96.99, validation loss=0.13
# Epoch 10: 54.29s, train acc=99.40, train loss=0.02, validation acc=97.47, validation loss=0.12
# Epoch 11: 61.63s, train acc=99.40, train loss=0.02, validation acc=97.58, validation loss=0.12
# Epoch 12: 67.65s, train acc=99.14, train loss=0.03, validation acc=97.12, validation loss=0.15
# Epoch 13: 75.82s, train acc=99.39, train loss=0.02, validation acc=97.44, validation loss=0.15
# ...
# Epoch 18: 107.64s, train acc=98.73, train loss=0.05, validation acc=97.28, validation loss=0.09
# Epoch 19: 113.82s, train acc=98.81, train loss=0.05, validation acc=97.36, validation loss=0.09
# Epoch 20: 118.81s, train acc=98.95, train loss=0.04, validation acc=97.40, validation loss=0.08
#
# Testing: adam optimizer, tanh activation, lr=0.01
# Epoch 1: 9.61s, train acc=96.45, train loss=0.12, validation acc=95.66, validation loss=0.15
# Epoch 2: 16.65s, train acc=97.05, train loss=0.10, validation acc=95.97, validation loss=0.13
# Epoch 3: 25.67s, train acc=97.27, train loss=0.09, validation acc=96.25, validation loss=0.13
# Epoch 4: 33.60s, train acc=98.11, train loss=0.06, validation acc=96.64, validation loss=0.11
# Epoch 5: 44.85s, train acc=98.37, train loss=0.05, validation acc=96.69, validation loss=0.11
# Epoch 6: 54.44s, train acc=98.45, train loss=0.05, validation acc=96.89, validation loss=0.11
# Epoch 7: 61.55s, train acc=98.63, train loss=0.04, validation acc=96.96, validation loss=0.11
# Epoch 8: 70.14s, train acc=98.72, train loss=0.04, validation acc=97.16, validation loss=0.10
# Epoch 9: 78.05s, train acc=98.63, train loss=0.04, validation acc=96.83, validation loss=0.12
# Epoch 10: 85.47s, train acc=98.86, train loss=0.03, validation acc=96.93, validation loss=0.11
# Epoch 11: 94.09s, train acc=98.83, train loss=0.03, validation acc=96.79, validation loss=0.12
# Epoch 12: 100.92s, train acc=99.02, train loss=0.03, validation acc=97.00, validation loss=0.11
# Epoch 13: 110.31s, train acc=99.09, train loss=0.03, validation acc=97.08, validation loss=0.11
# Epoch 14: 117.06s, train acc=99.31, train loss=0.02, validation acc=97.33, validation loss=0.10
# Epoch 15: 126.48s, train acc=98.92, train loss=0.03, validation acc=96.82, validation loss=0.12
# Epoch 16: 133.12s, train acc=99.17, train loss=0.03, validation acc=97.03, validation loss=0.12
# Epoch 17: 142.58s, train acc=99.07, train loss=0.03, validation acc=97.13, validation loss=0.12
# Epoch 18: 149.81s, train acc=99.11, train loss=0.03, validation acc=97.43, validation loss=0.11
# Epoch 19: 157.96s, train acc=99.31, train loss=0.02, validation acc=97.43, validation loss=0.11
# Epoch 20: 166.90s, train acc=98.70, train loss=0.04, validation acc=96.73, validation loss=0.14
#
# Testing: adam optimizer, tanh activation, lr=0.001
# Epoch 1: 6.86s, train acc=94.73, train loss=0.19, validation acc=94.29, validation loss=0.20
# Epoch 2: 16.53s, train acc=95.99, train loss=0.14, validation acc=95.39, validation loss=0.16
# Epoch 3: 23.37s, train acc=96.82, train loss=0.11, validation acc=95.97, validation loss=0.14
# Epoch 4: 32.88s, train acc=97.54, train loss=0.09, validation acc=96.55, validation loss=0.12
# Epoch 5: 39.90s, train acc=97.80, train loss=0.08, validation acc=96.72, validation loss=0.11
# Epoch 6: 49.20s, train acc=98.38, train loss=0.06, validation acc=97.16, validation loss=0.10
# Epoch 7: 56.49s, train acc=98.61, train loss=0.05, validation acc=97.20, validation loss=0.09
# Epoch 8: 65.07s, train acc=98.91, train loss=0.04, validation acc=97.46, validation loss=0.09
# Epoch 9: 74.02s, train acc=99.10, train loss=0.04, validation acc=97.52, validation loss=0.08
# Epoch 10: 80.73s, train acc=99.32, train loss=0.03, validation acc=97.75, validation loss=0.08
# Epoch 11: 89.66s, train acc=99.33, train loss=0.03, validation acc=97.58, validation loss=0.08
# Epoch 12: 96.47s, train acc=99.53, train loss=0.02, validation acc=97.66, validation loss=0.08
# Epoch 13: 105.79s, train acc=99.67, train loss=0.02, validation acc=97.76, validation loss=0.08
# Epoch 14: 112.54s, train acc=99.67, train loss=0.02, validation acc=97.75, validation loss=0.08
# Epoch 15: 121.99s, train acc=99.80, train loss=0.01, validation acc=97.82, validation loss=0.08
# Epoch 16: 129.09s, train acc=99.80, train loss=0.01, validation acc=97.80, validation loss=0.08
# Epoch 17: 138.19s, train acc=99.86, train loss=0.01, validation acc=97.87, validation loss=0.08
# Epoch 18: 145.43s, train acc=99.82, train loss=0.01, validation acc=97.78, validation loss=0.09
# Epoch 19: 153.67s, train acc=99.90, train loss=0.01, validation acc=97.88, validation loss=0.08
# Epoch 20: 161.84s, train acc=99.90, train loss=0.01, validation acc=97.84, validation loss=0.08
#
# Testing: adam optimizer, leaky_relu activation, lr=0.01
# Epoch 1: 4.47s, train acc=97.20, train loss=0.09, validation acc=96.07, validation loss=0.12
# Epoch 2: 8.97s, train acc=98.01, train loss=0.06, validation acc=96.95, validation loss=0.10
# Epoch 3: 16.01s, train acc=98.25, train loss=0.05, validation acc=96.90, validation loss=0.11
# Epoch 4: 20.50s, train acc=98.84, train loss=0.04, validation acc=97.11, validation loss=0.10
# Epoch 5: 25.08s, train acc=98.60, train loss=0.04, validation acc=96.84, validation loss=0.11
# Epoch 6: 31.90s, train acc=98.95, train loss=0.03, validation acc=97.17, validation loss=0.11
# Epoch 7: 36.24s, train acc=98.94, train loss=0.03, validation acc=97.33, validation loss=0.11
# Epoch 8: 41.83s, train acc=99.33, train loss=0.02, validation acc=97.49, validation loss=0.11
# Epoch 9: 47.49s, train acc=99.35, train loss=0.02, validation acc=97.57, validation loss=0.11
# Epoch 10: 51.77s, train acc=99.48, train loss=0.01, validation acc=97.68, validation loss=0.11
# Epoch 11: 57.61s, train acc=99.15, train loss=0.03, validation acc=97.40, validation loss=0.14
# Epoch 12: 62.79s, train acc=99.18, train loss=0.03, validation acc=97.04, validation loss=0.16
# Epoch 13: 67.20s, train acc=99.28, train loss=0.02, validation acc=97.19, validation loss=0.15
# Epoch 14: 74.23s, train acc=98.99, train loss=0.04, validation acc=97.00, validation loss=0.16
# Epoch 15: 78.73s, train acc=99.34, train loss=0.02, validation acc=97.36, validation loss=0.15
# Epoch 16: 83.14s, train acc=99.58, train loss=0.01, validation acc=97.45, validation loss=0.13
# Epoch 17: 90.27s, train acc=99.62, train loss=0.01, validation acc=97.38, validation loss=0.15
# Epoch 18: 94.62s, train acc=99.22, train loss=0.03, validation acc=96.95, validation loss=0.17
# Epoch 19: 98.92s, train acc=99.60, train loss=0.01, validation acc=97.66, validation loss=0.15
# Epoch 20: 105.76s, train acc=99.60, train loss=0.01, validation acc=97.47, validation loss=0.16
#
# Testing: adam optimizer, leaky_relu activation, lr=0.001
# Epoch 1: 4.24s, train acc=94.99, train loss=0.17, validation acc=94.93, validation loss=0.18
# Epoch 2: 9.10s, train acc=96.51, train loss=0.12, validation acc=95.92, validation loss=0.14
# Epoch 3: 15.32s, train acc=97.38, train loss=0.09, validation acc=96.52, validation loss=0.11
# Epoch 4: 19.73s, train acc=97.86, train loss=0.07, validation acc=96.92, validation loss=0.10
# Epoch 5: 25.50s, train acc=98.01, train loss=0.07, validation acc=96.73, validation loss=0.10
# Epoch 6: 31.09s, train acc=98.55, train loss=0.05, validation acc=97.38, validation loss=0.09
# Epoch 7: 35.56s, train acc=98.79, train loss=0.04, validation acc=97.43, validation loss=0.09
# Epoch 8: 42.26s, train acc=98.95, train loss=0.04, validation acc=97.60, validation loss=0.08
# Epoch 9: 46.80s, train acc=99.02, train loss=0.04, validation acc=97.47, validation loss=0.08
# Epoch 10: 51.16s, train acc=99.30, train loss=0.03, validation acc=97.61, validation loss=0.08
# Epoch 11: 58.32s, train acc=99.41, train loss=0.02, validation acc=97.70, validation loss=0.08
# Epoch 12: 63.00s, train acc=99.52, train loss=0.02, validation acc=97.68, validation loss=0.08
# Epoch 13: 67.60s, train acc=99.60, train loss=0.02, validation acc=97.69, validation loss=0.08
# Epoch 14: 74.56s, train acc=99.59, train loss=0.02, validation acc=97.76, validation loss=0.08
# Epoch 15: 79.10s, train acc=99.67, train loss=0.01, validation acc=97.75, validation loss=0.08
# Epoch 16: 84.84s, train acc=99.62, train loss=0.02, validation acc=97.58, validation loss=0.09
# Epoch 17: 90.68s, train acc=99.80, train loss=0.01, validation acc=97.76, validation loss=0.09
# Epoch 18: 95.15s, train acc=99.84, train loss=0.01, validation acc=97.70, validation loss=0.09
# Epoch 19: 101.69s, train acc=99.82, train loss=0.01, validation acc=97.79, validation loss=0.09
# Epoch 20: 106.12s, train acc=99.82, train loss=0.01, validation acc=97.64, validation loss=0.10
#
# Testing: adam optimizer, elu activation, lr=0.01
# Epoch 1: 5.03s, train acc=97.35, train loss=0.09, validation acc=96.44, validation loss=0.12
# Epoch 2: 12.65s, train acc=97.43, train loss=0.08, validation acc=96.38, validation loss=0.12
# Epoch 15: 91.92s, train acc=99.54, train loss=0.02, validation acc=97.67, validation loss=0.08
# Epoch 16: 99.86s, train acc=99.59, train loss=0.02, validation acc=97.61, validation loss=0.08
# Epoch 17: 105.14s, train acc=99.68, train loss=0.01, validation acc=97.77, validation loss=0.08
# Epoch 18: 112.39s, train acc=99.66, train loss=0.01, validation acc=97.86, validation loss=0.08
# Epoch 19: 117.92s, train acc=99.73, train loss=0.01, validation acc=97.79, validation loss=0.08
# Epoch 20: 123.28s, train acc=99.80, train loss=0.01, validation acc=97.74, validation loss=0.08
#
# Testing: adam optimizer, selu activation, lr=0.01
# Epoch 1: 7.58s, train acc=96.70, train loss=0.11, validation acc=95.86, validation loss=0.14
# Epoch 2: 13.35s, train acc=97.97, train loss=0.06, validation acc=96.91, validation loss=0.10
# Epoch 3: 21.15s, train acc=98.08, train loss=0.06, validation acc=96.75, validation loss=0.11
# Epoch 4: 26.20s, train acc=98.03, train loss=0.06, validation acc=96.46, validation loss=0.13
# Epoch 5: 32.98s, train acc=98.69, train loss=0.04, validation acc=97.15, validation loss=0.11
# Epoch 6: 38.93s, train acc=98.82, train loss=0.03, validation acc=97.31, validation loss=0.11
# Epoch 7: 44.11s, train acc=99.03, train loss=0.03, validation acc=97.40, validation loss=0.11
# Epoch 8: 51.65s, train acc=98.89, train loss=0.04, validation acc=97.20, validation loss=0.14
# Epoch 9: 56.67s, train acc=98.96, train loss=0.03, validation acc=97.23, validation loss=0.13
# Epoch 10: 64.50s, train acc=99.26, train loss=0.02, validation acc=97.41, validation loss=0.13
# Epoch 11: 69.62s, train acc=98.99, train loss=0.03, validation acc=97.08, validation loss=0.15
# Epoch 12: 75.29s, train acc=99.02, train loss=0.03, validation acc=97.08, validation loss=0.18
# Epoch 13: 81.98s, train acc=99.37, train loss=0.02, validation acc=97.57, validation loss=0.13
# Epoch 14: 87.06s, train acc=99.19, train loss=0.03, validation acc=97.38, validation loss=0.16
# Epoch 15: 94.78s, train acc=99.46, train loss=0.02, validation acc=97.64, validation loss=0.16
# Epoch 16: 99.92s, train acc=99.27, train loss=0.03, validation acc=97.32, validation loss=0.17
# Epoch 17: 106.39s, train acc=99.46, train loss=0.02, validation acc=97.46, validation loss=0.17
# Epoch 18: 112.24s, train acc=99.02, train loss=0.04, validation acc=97.03, validation loss=0.23
# Epoch 19: 117.19s, train acc=99.38, train loss=0.02, validation acc=97.65, validation loss=0.19
# Epoch 20: 124.70s, train acc=99.35, train loss=0.02, validation acc=97.39, validation loss=0.19
#
# Testing: adam optimizer, selu activation, lr=0.001
# Epoch 1: 5.19s, train acc=94.03, train loss=0.21, validation acc=93.84, validation loss=0.22
# Epoch 2: 12.90s, train acc=95.26, train loss=0.16, validation acc=94.92, validation loss=0.17
# Epoch 3: 17.99s, train acc=96.30, train loss=0.13, validation acc=95.78, validation loss=0.14
# Epoch 4: 23.35s, train acc=96.83, train loss=0.11, validation acc=96.03, validation loss=0.13
# Epoch 5: 30.68s, train acc=97.44, train loss=0.09, validation acc=96.50, validation loss=0.12
# Epoch 6: 35.75s, train acc=97.80, train loss=0.08, validation acc=96.66, validation loss=0.11
# Epoch 7: 43.40s, train acc=98.11, train loss=0.07, validation acc=96.70, validation loss=0.10
# Epoch 8: 48.58s, train acc=97.97, train loss=0.07, validation acc=96.55, validation loss=0.11
# Epoch 9: 54.51s, train acc=98.52, train loss=0.05, validation acc=96.92, validation loss=0.09
# Epoch 10: 60.49s, train acc=98.76, train loss=0.04, validation acc=97.15, validation loss=0.09
# Epoch 11: 65.47s, train acc=98.91, train loss=0.04, validation acc=97.18, validation loss=0.09
# Epoch 12: 73.18s, train acc=99.06, train loss=0.03, validation acc=97.32, validation loss=0.09
# Epoch 13: 78.35s, train acc=99.21, train loss=0.03, validation acc=97.42, validation loss=0.08
# Epoch 14: 85.39s, train acc=99.26, train loss=0.03, validation acc=97.29, validation loss=0.09
# Epoch 15: 90.44s, train acc=99.36, train loss=0.02, validation acc=97.37, validation loss=0.08
# Epoch 16: 95.61s, train acc=99.44, train loss=0.02, validation acc=97.36, validation loss=0.09
# Epoch 17: 103.20s, train acc=99.57, train loss=0.02, validation acc=97.37, validation loss=0.09
# Epoch 18: 108.34s, train acc=99.61, train loss=0.02, validation acc=97.53, validation loss=0.09
# Epoch 19: 115.95s, train acc=99.73, train loss=0.01, validation acc=97.62, validation loss=0.08
# Epoch 20: 120.97s, train acc=99.65, train loss=0.01, validation acc=97.53, validation loss=0.09
#
# Best configuration:
# Optimizer: adam
# Activation: relu
# Learning rate: 0.001
# Validation accuracy: 97.87%

# %%
for res in results:
    print(res)
# Out:
# {'optimizer': 'sgd', 'activation': 'relu', 'learning_rate': 0.01, 'val_accuracy': 95.87}
# {'optimizer': 'sgd', 'activation': 'relu', 'learning_rate': 0.001, 'val_accuracy': 90.49000000000001}
# {'optimizer': 'sgd', 'activation': 'sigmoid', 'learning_rate': 0.01, 'val_accuracy': 88.78}
# {'optimizer': 'sgd', 'activation': 'sigmoid', 'learning_rate': 0.001, 'val_accuracy': 47.699999999999996}
# {'optimizer': 'sgd', 'activation': 'tanh', 'learning_rate': 0.01, 'val_accuracy': 95.23}
# {'optimizer': 'sgd', 'activation': 'tanh', 'learning_rate': 0.001, 'val_accuracy': 90.02}
# {'optimizer': 'sgd', 'activation': 'leaky_relu', 'learning_rate': 0.01, 'val_accuracy': 96.00999999999999}
# {'optimizer': 'sgd', 'activation': 'leaky_relu', 'learning_rate': 0.001, 'val_accuracy': 90.66}
# {'optimizer': 'sgd', 'activation': 'elu', 'learning_rate': 0.01, 'val_accuracy': 95.28}
# {'optimizer': 'sgd', 'activation': 'elu', 'learning_rate': 0.001, 'val_accuracy': 90.45}
# {'optimizer': 'sgd', 'activation': 'selu', 'learning_rate': 0.01, 'val_accuracy': 95.53}
# {'optimizer': 'sgd', 'activation': 'selu', 'learning_rate': 0.001, 'val_accuracy': 91.25}
# {'optimizer': 'momentum', 'activation': 'relu', 'learning_rate': 0.01, 'val_accuracy': 95.84}
# {'optimizer': 'momentum', 'activation': 'relu', 'learning_rate': 0.001, 'val_accuracy': 90.78}
# {'optimizer': 'momentum', 'activation': 'sigmoid', 'learning_rate': 0.01, 'val_accuracy': 89.19}
# {'optimizer': 'momentum', 'activation': 'sigmoid', 'learning_rate': 0.001, 'val_accuracy': 50.129999999999995}
# {'optimizer': 'momentum', 'activation': 'tanh', 'learning_rate': 0.01, 'val_accuracy': 95.09}
# {'optimizer': 'momentum', 'activation': 'tanh', 'learning_rate': 0.001, 'val_accuracy': 90.53}
# {'optimizer': 'momentum', 'activation': 'leaky_relu', 'learning_rate': 0.01, 'val_accuracy': 96.07}
# {'optimizer': 'momentum', 'activation': 'leaky_relu', 'learning_rate': 0.001, 'val_accuracy': 90.79}
# {'optimizer': 'momentum', 'activation': 'elu', 'learning_rate': 0.01, 'val_accuracy': 94.75}
# {'optimizer': 'momentum', 'activation': 'elu', 'learning_rate': 0.001, 'val_accuracy': 90.35}
# {'optimizer': 'momentum', 'activation': 'selu', 'learning_rate': 0.01, 'val_accuracy': 95.48}
# {'optimizer': 'momentum', 'activation': 'selu', 'learning_rate': 0.001, 'val_accuracy': 91.29}
# {'optimizer': 'adam', 'activation': 'relu', 'learning_rate': 0.01, 'val_accuracy': 97.3}
# {'optimizer': 'adam', 'activation': 'relu', 'learning_rate': 0.001, 'val_accuracy': 97.87}
# {'optimizer': 'adam', 'activation': 'sigmoid', 'learning_rate': 0.01, 'val_accuracy': 97.72999999999999}
# {'optimizer': 'adam', 'activation': 'sigmoid', 'learning_rate': 0.001, 'val_accuracy': 97.39999999999999}
# {'optimizer': 'adam', 'activation': 'tanh', 'learning_rate': 0.01, 'val_accuracy': 96.73}
# {'optimizer': 'adam', 'activation': 'tanh', 'learning_rate': 0.001, 'val_accuracy': 97.84}
# {'optimizer': 'adam', 'activation': 'leaky_relu', 'learning_rate': 0.01, 'val_accuracy': 97.47}
# {'optimizer': 'adam', 'activation': 'leaky_relu', 'learning_rate': 0.001, 'val_accuracy': 97.64}
# {'optimizer': 'adam', 'activation': 'elu', 'learning_rate': 0.01, 'val_accuracy': 97.28}
# {'optimizer': 'adam', 'activation': 'elu', 'learning_rate': 0.001, 'val_accuracy': 97.74000000000001}
# {'optimizer': 'adam', 'activation': 'selu', 'learning_rate': 0.01, 'val_accuracy': 97.39}
# {'optimizer': 'adam', 'activation': 'selu', 'learning_rate': 0.001, 'val_accuracy': 97.53}

# %%
# Print best configuration
print("\nBest configuration:")
print(f"Optimizer: {best_config[0]}")
print(f"Activation: {best_config[1]}")
print(f"Learning rate: {best_config[2]}")
print(f"Validation accuracy: {best_val_acc:.2f}%")
# Out:
# Best configuration:
# Optimizer: adam
# Activation: relu
# Learning rate: 0.001
# Validation accuracy: 97.87%

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# Convert results to a DataFrame for easier manipulation
results_df = pd.DataFrame(results)

# 1. Bar Plot: Average validation accuracy for each optimizer
plt.figure(figsize=(8, 5))
sns.barplot(x='optimizer', y='val_accuracy', data=results_df, errorbar=None)
plt.title('Average Validation Accuracy by Optimizer')
plt.xlabel('Optimizer')
plt.ylabel('Validation Accuracy')
plt.show()

# 2. Heatmaps: Validation accuracy for activations and learning rates by optimizer
for opt in results_df['optimizer'].unique():
    plt.figure(figsize=(10, 6))
    pivot_table = results_df[results_df['optimizer'] == opt].pivot(
        index='activation', columns='learning_rate', values='val_accuracy'
    )
    sns.heatmap(pivot_table, annot=True, fmt='.2f', cmap='coolwarm')
    plt.title(f'Validation Accuracy Heatmap ({opt} Optimizer)')
    plt.xlabel('Learning Rate')
    plt.ylabel('Activation Function')
    plt.show()

# 3. Line Plot: Validation accuracy trends for different learning rates and optimizers
plt.figure(figsize=(12, 7))

# Custom color palette
colors = ['#FF6B6B', '#4ECDC4']  # Coral red and Turquoise
markers = ['o', 's', '^']  # Circle, Square, Triangle
line_styles = ['-', '--', '-.']

# Create the plot with custom styling
sns.set_style("whitegrid")
sns.set_palette(sns.color_palette(colors))

# Create the line plot
plot = sns.lineplot(
    data=results_df,
    x='activation',
    y='val_accuracy',
    hue='learning_rate',
    style='optimizer',
    markers=markers,
    dashes=False,
    markersize=10,
    linewidth=2.5
)

# Enhance the plot
plt.title('Validation Accuracy Across Different Configurations',
          fontsize=14,
          pad=20,
          fontweight='bold')
plt.xlabel('Activation Function', fontsize=12, labelpad=10)
plt.ylabel('Validation Accuracy (%)', fontsize=12, labelpad=10)

# Rotate x-axis labels and adjust their position
plt.xticks(rotation=45, ha='right')

# Customize legend
plt.legend(
    title='Learning Rate & Optimizer',
    title_fontsize=12,
    fontsize=10,
    bbox_to_anchor=(1.05, 1),
    loc='upper left'
)

# Add grid for better readability
plt.grid(True, linestyle='--', alpha=0.7)

# Adjust layout to prevent label cutoff
plt.tight_layout()

# Add a subtle background color
plot.set_facecolor('#F8F9FA')

# Customize spines
for spine in plot.spines.values():
    spine.set_edgecolor('#CCCCCC')

plt.show()

# %% [markdown]
# # MLP as function Approximator
# We know that a MLP with one hidden layer could  approximate any smooth function! <br> Here you will manually fit a sine function using ReLU activation. <br>You need to set the correct weights on ReLUs so the linear combination approximates the desired function.

# %%
def relu_approximation(input_data, target_labels):
    """
    Args:
      input_data: torch.tensor
        Input training data
      target_labels: torch.tensor
        Ground truth labels for training data

    Returns:
      activation_map: torch.tensor
        ReLU activations computed across the x-axis
      predicted_labels: torch.tensor
        Estimated labels or class predictions
        Derived from weighted sum of ReLU activations along the x-axis
      x_points: torch.tensor
        Points along the x-axis
    """
    ##############################---TODO---##############################
    # Number of ReLU units
    num_relus = input_data.shape[0] - 1 # except last input data

    # Generate dense x-axis points for interpolation
    x_points = torch.linspace(torch.min(input_data), torch.max(input_data), 1000)

    # Compute bias for ReLU units
    biases = input_data[:-1].squeeze() # except last input data

    # Initialize activation map to store ReLU activations
    activation_map = torch.zeros((num_relus, len(x_points)))

    for relu_idx in range(num_relus):
        activation_map[relu_idx, :] = torch.relu(x_points - biases[relu_idx])

    ## WEIGHTED SUM OF RELUS

    relu_weights = torch.zeros(num_relus)
    previous_slope = 0
    for j in range(num_relus):
        current_slope = (target_labels[j+1] - target_labels[j]) / (input_data[j+1] - input_data[j]) # delta y / delta x
        relu_weights[j] = current_slope - previous_slope
        previous_slope = current_slope

    # Compute predicted labels as weighted sum of ReLU activations
    predicted_labels = relu_weights @ activation_map # matmul
    ##############################---TODO---##############################

    return predicted_labels, activation_map, x_points


# Generate synthetic training data using sine function
num_samples = 10
input_data = torch.linspace(0, 2 * np.pi, num_samples).view(-1, 1) # training data
target_labels = torch.sin(input_data)

predicted_output, activation_map, x_points = relu_approximation(input_data, target_labels)
# predicted_output.shape, activation_map.shape, x_points.shape
plot_function_apx(x_points, activation_map, predicted_output)

# %% [markdown]
# # Depth vs. Width
# Here we wanna see the effect of width vs. depth on a classification task.First you are going to implement MLP again; But with 2 differences: <br>
#
# 1.   It is general purpose (i.e. works for desired depth and activation functions)
# 2.   You will implement it using pytorch

# %%
class MLP_pytorch(nn.Module):
  """
  Simulate MLP Network
  """

  def __init__(self, activation_fn, input_feature_num, hidden_unit_nums, output_feature_num):
    """
    Initialize MLP Network parameters

    Args:
      activation_fn: string
        Activation function
      input_feature_num: int
        Number of input features
      hidden_unit_nums: list
        Number of units per hidden layer. List of integers
      output_feature_num: int
        Number of output features

    Returns:
      Nothing
    """
    super(MLP_pytorch, self).__init__()
    self.input_feature_num = input_feature_num
    self.mlp = nn.Sequential()

    in_num = input_feature_num
    ##############################---TODO---##############################
    for i in range(len(hidden_unit_nums)):
        layer = nn.Linear(in_num, hidden_unit_nums[i])
        self.mlp.add_module(f'Linear_{i}', layer)

        if activation_fn == 'ReLU()':
            self.mlp.add_module(f'ReLU_{i}', nn.ReLU())
        elif activation_fn == 'Tanh()':
            self.mlp.add_module(f'Tanh_{i}', nn.Tanh())

        in_num = hidden_unit_nums[i]

    out_layer = nn.Linear(in_num, output_feature_num) # final layer
    self.mlp.add_module('Output_Linear', out_layer)

    ##############################---TODO---##############################

  def forward(self, x):
    """
    Simulate forward pass of MLP Network

    Args:
      x: torch.tensor
        Input data

    Returns:
      logits: Instance of MLP
        Forward pass of MLP
    """
    # Reshape inputs to (batch_size, input_feature_num)
    x = x.view(-1, self.input_feature_num)
    logits = self.mlp(x) # forward pass

    return logits

# %% [markdown]
# Now let's make a spiral dataset that follows this formula:
# \begin{equation}
# \begin{array}{c}
# X_{k}(t)=t\left(\begin{array}{c}
# \sin \left[\frac{2 \pi}{K}\left(2 t+k-1\right)\right]+\mathcal{N}\left(0, \sigma\right) \\
# \cos \left[\frac{2 \pi}{K}\left(2 t+k-1\right)\right]+\mathcal{N}\left(0, \sigma\right)
# \end{array}\right)
# \end{array}, \quad 0 \leq t \leq 1, \quad k=1, \ldots, K
# \end{equation}
#
# Run cell below to create the data and load it as tensors.

# %%
# @title Data Loader
K = 4
sigma = 0.4
N = 1000
t = torch.linspace(0, 1, N)
X = torch.zeros(K*N, 2)
y = torch.zeros(K*N)
for k in range(K):
  X[k*N:(k+1)*N, 0] = t*(torch.sin(2*np.pi/K*(2*t+k)) + sigma**2*torch.randn(N))
  X[k*N:(k+1)*N, 1] = t*(torch.cos(2*np.pi/K*(2*t+k)) + sigma**2*torch.randn(N))
  y[k*N:(k+1)*N] = k


X_test, y_test, X_train, y_train = shuffle_and_split_data(X, y, seed=SEED)

# DataLoader with random seed
batch_size = 128
g_seed = torch.Generator()
g_seed.manual_seed(SEED)

test_data = TensorDataset(X_test, y_test)
test_loader = DataLoader(test_data, batch_size=batch_size,
                         shuffle=False, num_workers=0,
                         worker_init_fn=seed_worker,
                         generator=g_seed,
                         )

train_data = TensorDataset(X_train, y_train)
train_loader = DataLoader(train_data,
                          batch_size=batch_size,
                          drop_last=True,
                          shuffle=True,
                          worker_init_fn=seed_worker,
                          generator=g_seed,
                          )

# %% [markdown]
# Now we will add more polynomial features to the dataset to make the first layer wider. Afterwards, train a single linear layer. We could use the same MLP network with no hidden layers (though it would not be called an MLP anymore!).
#
# Add polynomial terms up to $P=50$ which means that for every $x_1^n x_2^m$ term, $n+m\leq P$. Total number of polynomial features up to $P$ follows this formula:
#
# \begin{equation}
# \text{# of terms} = \frac{(P+1)(P+2)}{2}
# \end{equation}
#
# Also, we don't need the polynomial term with degree zero (which is the constatnt term) since `nn.Linear` layers have bias terms. Therefore we will have one fewer polynomial feature.

# %%
def polynomial_classifier(poly_degree, seed=0):
  """
  Helper function to run the polynomial classifier

  Args:
    poly_degree: int
      Degree of the polynomial
    seed: int
      A non-negative integer that defines the random state.

  Returns:
    num_features: int
      Number of features
  """

  def polynomial_features(poly_degree, X):
    """
    Function to define the number of polynomial features except the bias term

    Args:
      poly_degree: int
        Degree of the polynomial
      X: torch.tensor
        Input data

    Returns:
      num_features: int
        Number of features
      poly_X: torch.tensor
        Polynomial term
    """
    ##############################---TODO---##############################
    num_features = (poly_degree + 1) * (poly_degree + 2) // 2 - 1  # -1 for excluding constant term (degree zero)
    poly_X = torch.zeros((X.shape[0], num_features))

    feature_idx = 0
    for i in range(1, poly_degree + 1):
        for j in range(i + 1):
            if i - j >= 0:
                poly_X[:, feature_idx] = (X[:, 0] ** (i - j)) * (X[:, 1] ** j)
                feature_idx += 1

    return poly_X, num_features
    ##############################---TODO---##############################

  poly_X_test, num_features = polynomial_features(poly_degree, X_test)
  poly_X_train, _ = polynomial_features(poly_degree, X_train)

  batch_size = 128

  g_seed = torch.Generator()
  g_seed.manual_seed(seed)
  poly_test_data = TensorDataset(poly_X_test, y_test)
  poly_test_loader = DataLoader(poly_test_data,
                                batch_size=batch_size,
                                shuffle=False,
                                num_workers=1,
                                worker_init_fn=seed_worker,
                                generator=g_seed)

  poly_train_data = TensorDataset(poly_X_train, y_train)
  poly_train_loader = DataLoader(poly_train_data,
                                 batch_size=batch_size,
                                 shuffle=True,
                                 num_workers=1,
                                 worker_init_fn=seed_worker,
                                 generator=g_seed)

  # Defining a linear model using MLP class
  poly_net = MLP_pytorch('ReLU()', num_features, [], K)

  # Train and test
  criterion = nn.CrossEntropyLoss()
  optimizer = optim.Adam(poly_net.parameters(), lr=1e-3)
  _, _ = train_test_classification(poly_net, criterion, optimizer,
                                   poly_train_loader, poly_test_loader,
                                   num_epochs=100)
  X_all = sample_grid()
  poly_X_all, _ = polynomial_features(poly_degree, X_all)
  y_pred = poly_net(poly_X_all)

  # Plot
  plot_decision_map(X_all.cpu(), y_pred.cpu(), X_test.cpu(), y_test.cpu())
  plt.show()

  return num_features

# %% [markdown]
# ### Train the network. How does it generalize?

# %%
seed_setter(seed=SEED)
max_poly_deg = 50
num_features = polynomial_classifier(max_poly_deg)
print(f'Number of features: {num_features}')
# Out:
# Random seed 2024 has been set.
#   0%|          | 0/100 [00:00<?, ?it/s]
# Accuracy on the 3200 training samples: 69.94
# Accuracy on the 800 testing samples: 69.12
# Number of features: 1325

# %% [markdown]
# Now create another instance of `MLP_pytorch` class having a hidden layer of 128 neurons and train it. Compare the result with the wide network. How does deeper model generalize? Is the decision boundaries ideal? Why?
#
# As you can see the results are as follows:
# - deeper model test accuracy: **98%**
# - wider model test accuracy: **69.12**
#
# The deeper model with a hidden layer produce more ideal, smoother, and more generalized decision boundaries compared to the wide network (polynomial classifier). This is because:
#
# - The ReLU activation functions provide nonlinear transformations that can better capture the spiral pattern
# - The hidden layer allows the network to learn hierarchical features and more abstract features (Hierarchical Feature Learning)
# - The polynomial features might overfit to the training data (and noise) due to the high number of features, while the deeper model can learn more generalizable patterns
# - Representational Power: Despite having fewer neurons, the deep network can capture more complex patterns

# %%
##############################---TODO---##############################
seed_setter(SEED)
net2 = MLP_pytorch('ReLU()', 2, [128], K)  # 2 input features, 128 hidden neurons, K outputs
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(net2.parameters(), lr=1e-3)
num_epochs = 100

_, _ = train_test_classification(net2, criterion, optimizer, train_loader,
                                 test_loader, num_epochs=num_epochs,
                                 training_plot=True)

X_all = sample_grid()
y_pred = net2(X_all).cpu()
plot_decision_map(X_all, y_pred, X_test, y_test)

##############################---TODO---##############################
# Out:
# Random seed 2024 has been set.
#   0%|          | 0/100 [00:00<?, ?it/s]
# Accuracy on the 3200 training samples: 97.75
# Accuracy on the 800 testing samples: 98.00
